# %% [markdown]
# # STAT 530 Homework 8
#
#
# ## Instructions
#
# You may use any packages you'd like. Some analyses are most easily done without packages. In these cases you will need to formulate the problem correctly, by identifying the population, the features, the question type, etc. Multiple answers are possible.
#
# Export your solutions to HTML and submit the HTML file on Canvas.

# %% [markdown]
# ## Problem 1 (2 points)
#
# Using scanpy, normalize the spots in sample GSM6939158_Sample5HC and then cluster spots that appear transcriptionally similar. Find enough clusters such that the subregions of the hippocampus separate into different clusters (1 point). Visualize the clusters on the tissue section (1 point).

# %% [markdown]
# ## Problem 2 (3 points)
#
# Mosharov et al. (2025) [https://www.nature.com/articles/d41586-025-00848-z](https://www.nature.com/articles/d41586-025-00848-z) published a map of mitochondria in the human brain in what has been called a "groundbreaking" achievement. Among other findings, they reported that gray matter has more mitochondria than white matter. Test whether or not this is true in the mouse brain using sample GSM6939158_Sample5HC. Identify which spots contain white matter versus gray matter and visualize (1 point), visualize the amount of mitochondria per spot (1 point), and conduct your test and report the p-value (1 point).
